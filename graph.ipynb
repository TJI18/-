# %%
# NetworkXを使ってみる
import random
import networkx as nx
#%matplotlib inline

graph = nx.MultiGraph()
f = open('input.txt','r')
for line in f.readlines():
  u, v = map(int, line.split())
  graph.add_edge(u, v)
  # print(u, v)

nx.draw_networkx(graph)
